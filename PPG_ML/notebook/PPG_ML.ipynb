# %% [markdown]
# Mount project from google drive to google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Map project to colab local directory

# %%
import os
import sys

# 项目在 Google Drive 的路径
project_path = "/content/drive/MyDrive/PPG_ML"

# 切换到项目目录
os.chdir(project_path)

# 加入 Python 搜索路径
sys.path.append(project_path)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/drive/MyDrive/PPG_ML

# %% [markdown]
# Install requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Run preprocess scripts for PPG-DaLiA

# %%
# !pip install hydra-core
# %cd /content/drive/MyDrive/PPG_ML
# !python3 -m scripts.preprocess_dalia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 4.1 MB/s eta 0:00:00
# ...
# /content/drive/MyDrive/PPG_ML
#
#  [PPG-DaLiA] 读取目录: /content/drive/MyDrive/PPG_ML/data/raw/dalia
#  [PPG-DaLiA] 找到 15 个受试者文件
# Processing subjects: 100% 15/15 [09:47<00:00, 39.16s/it]
#
#  ======= FINAL SHAPES ========
# PPG : (129444, 1, 256)
# STFT: (129444, 1, 65, 9)
# MEL : (129444, 1, 32, 9)
# MASK: (129444, 1, 256)
# HR  : (129444,)
#
# [FINISHED] 已保存到: /content/drive/MyDrive/PPG_ML/data/processed/dalia

# %% [markdown]
# check processed data from DaLiA

# %%
# %cd /content/drive/MyDrive/PPG_ML
# !python3 -m scripts.check_dalia_processed
# Out:
# /content/drive/MyDrive/PPG_ML
# == Checking file existence ==
#   ✓ ppg.npy found
#   ✓ stft.npy found
#   ✓ mel.npy found
#   ✓ mask.npy found
#   ✓ hr.npy found
#
# == Loading npy files ==
# PPG shape : (129444, 1, 256)
# STFT shape: (129444, 1, 65, 9)
# MEL shape : (129444, 1, 32, 9)
# MASK shape: (129444, 1, 256)
# HR shape  : (129444,)
#
# == Basic dimension checks ==
# ✓ All batch sizes match
# Checking PPG NaN/inf...
#  ✓ PPG clean
# Checking STFT NaN/inf...
#  ✓ STFT clean
# Checking MEL NaN/inf...
#  ✓ MEL clean
# Checking MASK NaN/inf...
#  ✓ MASK clean
# Checking HR NaN/inf...
#  ✓ HR clean
#
# == Checking MASK ==
# Unique values in mask: [0. 1.]
# ✓ Mask is binary (0/1)
#
# == Checking HR ==
# HR range: 41.69084930419922 ~ 187.0154266357422
# ✓ HR values reasonable
# Saving visualization for sample #0
# ✓ Saved to: /content/drive/MyDrive/PPG_ML/plots/dalia/sample_0.png
# Saving visualization for sample #10
# ...

# %% [markdown]
# Run preprocess scripts for BAMI

# %%
# %cd /content/drive/MyDrive/PPG_ML
# !python3 scripts/preprocess_bami.py
# Out:
# /content/drive/MyDrive/PPG_ML
#
# ==== Processing bami1 from /content/drive/MyDrive/PPG_ML/data/raw/BAMI/BAMI-1 ====
# [BAMI1_1.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_10.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_11.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_12.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_13.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_14.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_15.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_16.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_17.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_18.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_19.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_2.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# [BAMI1_20.mat] T=42000, N_hr=417, fs_est≈100.72, fs_src=101
# [BAMI1_21.mat] T=31501, N_hr=312, fs_est≈100.96, fs_src=101
# ...

# %% [markdown]
# check processed data from BAMI

# %%
# %cd /content/drive/MyDrive/PPG_ML
# !python3 scripts/check_bami_processed.py
# Out:
# /content/drive/MyDrive/PPG_ML
# Root: /content/drive/MyDrive/PPG_ML
#
# ================ CHECKING: bami1 ================
# == Checking files ==
#   ✓ ppg.npy found
#   ✓ stft.npy found
#   ✓ mel.npy found
#   ✓ mask.npy found
#   ✓ hr.npy found
#
# == Loading arrays ==
# PPG shape : (9102, 1, 256)
# STFT shape: (9102, 1, 65, 9)
# MEL shape : (9102, 1, 64, 9)
# MASK shape: (9102, 1, 256)
# HR shape  : (9102,)
#
# == Dimension checks ==
# ✓ All dimensions OK
#
# == NaN / Inf checks ==
#   ✓ PPG clean
#   ✓ STFT clean
#   ✓ MEL clean
#   ✓ MASK clean
#   ✓ HR clean
#
# == HR Stats ==
# HR range: 67.57 ~ 187.84
#
# == Visualizing sample ==
# Plot sample index: 1121
#   STFT squeezed shape: (65, 9)
#   MEL squeezed shape : (64, 9)
# Saved visualization to: /content/drive/MyDrive/PPG_ML/plots/bami_sample_1121.png
# === CHECK FINISHED ===
#
# ================ CHECKING: bami2 ================
# == Checking files ==
#   ✓ ppg.npy found
#   ✓ stft.npy found
#   ✓ mel.npy found
# ...
